# %% [markdown]
# # Lesson 7: Mini Project 🎉🐍
#
# Welcome back to **LearnTech with Robert**!
# You’ve learned a lot over the past lessons — variables, conditionals, loops, functions, lists, and dictionaries. Now it’s time to **put it all together** and build a small, interactive program. This is your chance to **practice everything you’ve learned** in a fun, creative way!
#
# Mini projects help you **see how concepts work together** in real programs. By doing this, you’ll build confidence and start thinking like a real programmer 💪
#
# ---
#
# ## 📘 What You’ll Learn
#
# By the end of this lesson, you will be able to:
#
# - Combine variables, conditionals, loops, and functions
# - Build a small interactive Python program
# - Use lists and dictionaries to store data
# - Customize a project to your liking
#
# ---
#
# ## 🧠 Planning Your Mini Project
#
# ### Explanation
# Before writing code, it’s important to **plan what your program will do**.
#
# Ask yourself:
# - What is the program for? (e.g., a quiz, a to-do list, a simple game)
# - What inputs will the user give?
# - What outputs will the program show?
# - Which Python concepts will you use?
#
# ### Why This Matters
# Planning keeps your code organized and helps you avoid confusion. Even professional developers plan before coding.
#
# ---
#
# ## ✅ Task 1: Define the Program’s Purpose
#
# - Decide what your interactive program will do (e.g., quiz, calculator, guessing game)
# - Write down a list of actions the program will perform
# - Identify which Python concepts (variables, loops, functions, conditionals) you will use
#
# ### 🧠What’s happening?
# - You’re thinking like a programmer
# - Planning makes writing code easier
# - You’ll know which tools to use before typing anything
#
# ### ✏️ Your Turn
# 1. Choose a program idea
# 2. List the main steps your program will follow
# 3. Identify at least 3 Python concepts you will use
#
# *Hint: Keep it simple but interactive*
#
# ---
#
# ## 🛠️ Setting Up the Program Structure
#
# A program works best when **broken into sections**:
# 1. Gather input from the user
# 2. Process the input using logic and loops
# 3. Show output
#
# Functions are great for **grouping tasks** and avoiding repetitive code.
#
# Organizing code makes it readable, easier to debug, and reusable.
#
# ---
#
# ## ✅ Task 2: Create Functions for Your Program
#
# ```python
# def greet_user():
#     print("Welcome to my mini project!")
#
# def get_input():
#     name = input("What is your name? ")
#     return name
# ```
# ### 🧠 What’s happening?
# - `greet_user()` handles the welcome message
# - `get_input()` asks the user's naame and returns it
# - Functions keep your code **clean and modular**
#
# ## ✏️ Your Turn
# 1. Write a function to greet the user
# 2. Write another function to ask for a user input
# 3. Call bboth functions in order

# %%
# Hint: Once you run a cell every other cell can use the information from the cell!

# %% [markdown]
# ---
# ## 🔄 Using Loops and Conditionals
# ### Explanation
#
# Loops let your program **repeat actions**, while conditionals let it make decisions. Combining these makes programs interactive.
#
# Example: Repeating a quiz until the user wants to stop, or giving feedback based on user input.
#
# ### Why This Matters
# Most interactive programs need repetition and **decision-making** — loops and conditionals are essential building blocks.
#
# ---
# ## ✅ Task 2: using `range()` with Numbers
# ```python
# while True:
#     choice = input("Type 'yes' to continue or 'no' to quit: ")
#     if choice == "no":
#         print("Goodbye!")
#         break
#     else:
#         print("You chose to continue!")
#
#
# ```
# ### 🧠 What’s happening?
# - The `while True` loop runs indefinitely until `break` is called
# - `if checks the user input
# - Program reacts differently based on input
#
# ## ✏️ Your Turn
# 1. Add a loop to your mini project
# 2. Use conditionals to respond to user input
# 3. Allow the user to repeat an action or quit

# %%
# Don't be afraid to go to past content for ideas!

# %% [markdown]
# ---
# ## 📦 Using Lists and Dictionaries
# ### Refresher:
#
# Lists and dictionaries let you store multiple pieces of information your program may need.
#
# Examples:
# - A to-do list storing tasks
# - A quiz storing questions and answers
# - A simple contact book storing naames and emails
# -
# ### Why This Matters
# Real programs usually handle lots of data. Lists and dictionaries make it organized and accessible.
#
# ---
# ## ✅ Task 4: Store Data in Your Program
# ```python
# scores = []
# scores.append(10)
# scores.append(15)
#
# print("Scores recorded:", scores)
#
# quiz = {"question": "What is 2 + 2?", "answer": 4}
# print("Quiz question:", quiz["question"])
#
#
# ```
# ### 🧠 What’s happening?
# - `scores` stores multiple numbers
# - `quiz` stores a key-value pair
# - Data is easily accessible and modifiable
#
# ## ✏️ Your Turn
# 1. Use a list or dictionary in your mini project
# 2. Add at least two items to it
# 3. Retrieve and print one of the items

# %%
# Don't be afraid to go to past content for ideas!

# %% [markdown]
# ---
# # 🌟 Optional Challenge
#
# ## 💡 Add customization to your project:
# - Let the user enter muiltiple inputs into a list
# - Use a dictionary to track scores, levels, or answers
# - Add a loop to repeat a part of your program
# - Include a function that calculates something (sum, average, or score)
#
# 💡 Think creatively and combine all Python concepts you’ve learned so far.

# %% [markdown]
# # ✅ Lesson Summary
#
# 🎉 **Congratulations!**
#
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExeDA4emxwaTN5bDN0NTh5eGFqNm5mZjV3ajV4dHQybmxoYjRlMjZmdSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/1PMVNNKVIL8Ig/giphy.gif" width="300"/>
#
# You’ve built your first interactive program combining multiple Python concepts:
# - Variables that store user input and data
# - Functions that organize code into reusable blocks
# - Loops that allow for repeatable actions
# - Conditionals that make dicisions
# - Lists and dictionaries to store multiple values effficiently
#
# Mini projects are how you really start thinking like a programmer. The more you experiment, the better you get!
#
# Next up: You’re ready to explore more advanced Python projects and libraries 🚀
# Keep building, keep experimenting, and have fun! 🎉
