# %% [markdown]
# # Lesson 1: Hello World 🐍
#
# Welcome to your first step in learning Python with *LearnTech with Robert*!
#
# In this lesson, we’ll cover:
# - What Python is and why it’s popular
# - How to write your first Python code
# - Basic programming concepts: variables and data types
# - How to run code in Jupyter Notebook
#
# Let's get started! 🎉

# %% [markdown]
# ## What is Python?
#
# Python is a **high-level programming language** that is:
# - Easy to read and write
# - Widely used in web development, data science, AI, and automation
# - Beginner-friendly with a clean syntax
#
# Python allows you to **turn ideas into code quickly**, making it perfect for beginners.

# %% [markdown]
# ## Task 0 – Hello, World! 🌟
# So you've heard that using Python to get your computer to print "Hello, World!" to your screen is your official initiation to the club of coders. Let's make sure you're in.
#
#
# Use a variable called `greeting` to store the text, then use the `print()` function to display it.

# %%
# Task 0
greeting = "Hello, World!"
print(greeting)
# Out:
# Hello, World!

# %% [markdown]
# 💡 **Try this:** Change the message inside the quotes to say something about yourself. For example:
#
# ```python
# print("Hello World! My name is ___ and I am learning Python!")

# %%
# Your turn! (Click this cell and press Shift + Enter to run)
print(f"{greeting}! My name is _____ and I am learning Python!")
# Out:
# Hello, World!! My name is _____ and I am learning Python!

# %% [markdown]
# <div style="border: 3px solid #b67ae5; background-color: #f9f1ff; padding: 15px; border-radius: 8px; color: #222; display: flex; align-items: center;">
# <span style="font-size: 10pt;">
# <strong>Tip: </strong>Click the above cell to edit and press Shift + Enter to run
# </span>
# </div>

# %% [markdown]
# 🎉 **Mission Accomplished!**
# You just printed `"Hello, World!"` and officially entered the world of programming.
#
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExeDA4emxwaTN5bDN0NTh5eGFqNm5mZjV3ajV4dHQybmxoYjRlMjZmdSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/1PMVNNKVIL8Ig/giphy.gif" width="300"/>
#
# Let’s keep the momentum going—on to the next task!

# %% [markdown]
# ## 4️⃣ Python Basics: Variables & Data Types 🐍
#
# 🎉 **Congratulations!** You are now officially a programmer!
#
# In this next section, we'll learn about **variables**, which are like containers for storing information, and **data types**, which tell Python what kind of data you're working with.
# ### Variables & Data Types
#
# Variables are like containers for storing information. Examples of basic data types:
# - **String** (text): "Hello"
# -  **Integer** (whole numbers): 42
# - **Float** (decimal numbers): 3.14
# - **Boolean** (True/False): True

# %% [markdown]
# ## Task 1: Introduce Yourself 👤
#
# Now that you’re officially a programmer, let’s tell Python a bit about you!
#
# Variables are like little **containers** that hold information. We’ll make a few to describe you:
#
# - **Name** – What should Python call you?
# - **Age** – How old are you in human years?
# - **Height** – How tall are you? (use a number with a decimal, like 5.9)
# - **is_human** – Are you human? True or False
#
# Go ahead and fill in the variables below. Don’t worry, Python won’t judge! 😄

# %%
# Introduce yourself to Python
name = "Your Name"
age = 0
height = 0.0
is_human = True

# Print your info so Python knows you exist!
print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Are you human?", is_human)
# Out:
# Name: Your Name
# Age: 0
# Height: 0.0
# Are you human? True

# %% [markdown]
# ## Task 2: Favorite Food 🍕🍦
#
# Even coders need to eat! Let’s tell Python your **favorite food**.
#
# Create a variable called `favorite_food` and store your favorite snack. Then, show Python how to tell the world what it is using a **f-string**.
#
# Example:
# ```python
# favorite_food = "Pizza"
# print(f"My favorite food is {favorite_food}")

# %%
# What's your favorite food?
favorite_food = "Your favorite food"
print(f"My favorite food is {favorite_food}")
# Out:
# My favorite food is Your favorite food

# %% [markdown]
# ## Task 3: Combine Your Story ✨
#
# Python loves stories, and now it’s time to **combine everything you’ve created** into one little narrative.
#
# Use an f-string to introduce yourself and your favorite food in one sentence. Something like this:
#
# ```python
# print(f"My name is {name}, I am {age} years old, and I love {favorite_food}!")

# %%
# Combine your variables into one story
print(f"My name is {name}, I am {age} years old, and I love {favorite_food}!")
# Out:
# My name is Your Name, I am 0 years old, and I love Your favorite food!

# %% [markdown]
# ## Summary of Lesson 1 ✅
#
# Congratulations! You’ve officially started your journey as a Python programmer.
#
# Here’s what you learned today:
# - How to print messages with `print()` 🗨️
# - How to store information in variables 📦
# - Basic Python data types: string, integer, float, boolean
# - How to combine text and variables with f-strings ✨
#
# Next up: **Lesson 2 – Variables and Data Types in Depth**, where we’ll explore more ways to store and manipulate information.
#
# 🎉 Keep experimenting and have fun!
